# %% [markdown]
# <a href="https://colab.research.google.com/github/unatardedemartes-a11y/ClassFiles/blob/main/Laboratorio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 2

# %% [markdown]
# # Carga y revision inicial

# %% [markdown]
# Cargar archivo desde el drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Abrir el archivo de forma segura

# %%
with open('/content/drive/MyDrive/ClassFiles/informe_acciones.txt', 'r') as archivo:
    # Lee todo el contenido del archivo
    print (archivo)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/ClassFiles/informe_acciones.txt' mode='r' encoding='utf-8'>

# %% [markdown]
# # Objetivos

# %% [markdown]
#  El archivo contiene varios correos electrónicos en donde se informa el valor de las acciones de diferentes empresas. El código deberá extraer el valor actual de las acciones que aparecen en cada correo electrónico e imprimirlo a pantalla. En este ejercicio debeás utilizar Expresiones Regulares
